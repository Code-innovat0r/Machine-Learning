# %%
# Navie Bayes Algorithm

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('Social_Network_Ads.csv')

# %%
x_train,x_test,y_train,y_test = train_test_split(data.iloc[:,2:4], data.iloc[:,4], random_state=0, train_size=0.80)

# %%
y_train.shape
# Out:
# (320,)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB

# %%
obj = make_pipeline(StandardScaler(), GaussianNB())

# %%
obj.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gaussiannb', GaussianNB())])

# %%
y_pred = obj.predict(x_test)

# %%
from sklearn.metrics import accuracy_score as score

# %%
print("Accuracy score is : ", score(y_pred, y_test))
# Out:
# Accuracy score is :  0.9125

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_test.iloc[:,0],x_test.iloc[:,1],c = y_test)

# %%
plt.scatter(x_test.iloc[:,0],x_test.iloc[:,1],c = y_pred)
