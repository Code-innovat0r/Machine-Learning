# %%
import pandas as pd
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
x=iris.data

# %%
y=iris.target

# %%
from sklearn.ensemble import RandomForestClassifier
obj = RandomForestClassifier( random_state=0)

# %%
from sklearn.model_selection import train_test_split

# %%
x_tr,x_ts,y_tr,y_ts = train_test_split(x,y,random_state=0,train_size=0.75)

# %%
obj.fit(x_tr,y_tr)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pr = obj.predict(x_ts)

# %%
y_pr
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 2])

# %%
from sklearn.metrics import accuracy_score as score

# %%
print('Accuracy score: ', score(y_ts, y_pr))
# Out:
# Accuracy score:  0.9736842105263158

# %%
# Doing this prediction using the single decision tree and then compare the accuracy

# %%
# Entropy

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dec = DecisionTreeClassifier(criterion='entropy', splitter='random', random_state=0)

# %%
dec.fit(x_tr,y_tr)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0, splitter='random')

# %%
y_predict = dec.predict(x_ts)

# %%
print("Accuracy: ", score(y_ts,y_predict))
# Out:
# Accuracy:  0.9736842105263158

# %%
# gini

# %%
dec1 = DecisionTreeClassifier(criterion='gini', splitter='random', random_state=0)

# %%
dec1.fit(x_tr,y_tr)
# Out:
# DecisionTreeClassifier(random_state=0, splitter='random')

# %%
y_predict1 = dec1.predict(x_ts)

# %%
print('Accuracy: ', score(y_ts, y_predict1))
# Out:
# Accuracy:  0.9736842105263158
