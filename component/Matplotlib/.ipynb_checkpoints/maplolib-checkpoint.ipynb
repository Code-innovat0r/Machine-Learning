# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
x =  np.array([0 , 10]) # array contain the 2 element 0, 10
y = np.array([0, 300]) # array contain the 2 element 0, 300

# %%
x
# Out:
# array([ 0, 10])

# %%
y
# Out:
# array([  0, 300])

# %%
# plotting the x, y on the graph
plt.plot(x,y)
plt.show()

# %%
# plt.xlabel('freq')
# plt.ylabel('count')
plt.plot(x, y, 'o') # print the two dots
plt.show()

# %%
# creating the array of 8 elements, for ploting both the x, y should equal length then only the coordinate(x,y) form. If length is not equal then it will be an error
x = np.array([1,2,3,4,5,6,7,8]) 
y = np.array([2,4,6,8,10,12,14,16])

# %%
x.shape
# Out:
# (8,)

# %%
y.shape
# Out:
# (8,)

# %%
plt.plot(x,y)

# %%
plt.plot(x, y, 'o')

# %%
x = [1,2,3,4]
y = [4,4,4,4]

# %%
plt.plot(x,y)

# %%
z = np.array([2,4,67,23,89,5,45,2])

# %%
# plt.xlabel("paras")
# plt.ylabel("kumar")
plt.plot(z)

# %%
plt.plot(z, marker = 'o')

# %%
plt.plot(z, 'o:b')

# %%
# ms - marker size 
plt.plot(z, '+:b', ms = 15)

# %%
plt.plot(z, '+:b', ms = 15, mec = 'r')
